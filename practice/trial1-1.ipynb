# %%
import numpy as np
import matplotlib.pyplot as plt
from control.matlab import *
from control import bode, tf
from control.matlab import logspace

# %%
kp_s = np.arange(0.01, 2, 0.1)
plt.figure(1)
plt.subplot(2,1,1)
plt.ylim(-60, 40)
plt.yticks(np.arange(-60, 41, 20))
plt.xlim(1e-1, 1e3)
plt.subplot(2,1,2)
plt.ylim(-360, 0)
plt.yticks(np.arange(-360, 1, 90))
plt.xlim(1e-1, 1e3)
fig1, fig2 = plt.gcf().axes # subplotのハンドラを取得
for kp in range(len(kp_s)):
    S = tf([1, 0],[1, kp])
    mag, phase, om = bode(S, plot = False)
    plt.sca(fig1)
    plt.semilogx(om, 20*np.log10(mag))
    plt.sca(fig2)
    plt.semilogx(om, phase*180/np.pi)
plt.sca(fig1)
plt.xticks([])
# Out:
# ([], [])

# %%
kp_s = np.arange(0.01, 2, 0.1)
plt.figure(1)
plt.subplot(2,1,1)
plt.ylim(-60, 40)
plt.yticks(np.arange(-60, 41, 20))
plt.xlim(1e-1, 1e3)
plt.subplot(2,1,2)
plt.ylim(-360, 0)
plt.yticks(np.arange(-360, 1, 90))
plt.xlim(1e-1, 1e3)
fig1, fig2 = plt.gcf().axes # subplotのハンドラを取得
for kp in range(len(kp_s)):
    S = tf([0, kp],[1, kp])
    mag, phase, om = bode(S, plot = False)
    plt.sca(fig1)
    plt.semilogx(om, 20*np.log10(mag))
    plt.sca(fig2)
    plt.semilogx(om, phase*180/np.pi)
plt.sca(fig1)
plt.xticks([])
# Out:
# C:\Users\takahashi\AppData\Local\Temp\ipykernel_34828\837778634.py:16: RuntimeWarning: divide by zero encountered in log10
#   plt.semilogx(om, 20*np.log10(mag))
# ([], [])

# %%
kp_s = np.arange(0.01, 2, 0.1)
plt.figure(1)
plt.subplot(2,1,1)
plt.ylim(-60, 40)
plt.yticks(np.arange(-60, 41, 20))
plt.xlim(1e-1, 1e3)
plt.subplot(2,1,2)
plt.ylim(-360, 0)
plt.yticks(np.arange(-360, 1, 90))
plt.xlim(1e-1, 1e3)
fig1, fig2 = plt.gcf().axes # subplotのハンドラを取得
for kp in range(len(kp_s)):
    S = tf([0, 1],[1, kp])
    mag, phase, om = bode(S, plot = False)
    plt.sca(fig1)
    plt.semilogx(om, 20*np.log10(mag))
    plt.sca(fig2)
    plt.semilogx(om, phase*180/np.pi)
plt.sca(fig1)
plt.xticks([])
# Out:
# ([], [])
